# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID       City Country  Max Temp Current Description      Lat  \
# 0        5      Vaini      TO     78.96    scattered clouds -21.2000
# 1        8   Souillac      MU     84.58          few clouds -20.5167
# 2        9   Sehithwa      BW     78.12     overcast clouds -20.4667
# 3       11     Yarada      IN     84.52       broken clouds  17.6500
# 4       13  La Romana      DO     76.73           clear sky  18.4273
#
#         Lng                       Hotel Name
# 0 -175.2000              Keleti Beach Resort
# 1   57.5167      Shanti Maurice Resort & Spa
# 2   22.7167               MONLEK GUEST HOUSE
# 3   83.2667                        Vishranti
# 4  -68.9728  Casa de Campo Resort and Villas

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temperature</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

hotel_info
# Out:
# ['\n<dl>\n<dt>City Name</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>78.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>84.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Sehithwa</dd>\n<dt>Country</dt><dd>BW</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Yarada</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>84.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>La Romana</dd>\n<dt>Country</dt><dd>DO</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>76.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>75.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>84.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Tezu</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>85.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kupang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>thunderstorm</dd>\n<dt>Max Temperature</dt><dd>79.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Lubao</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>83.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Barabai</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>79.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Moroni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>84.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Banda Aceh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>84.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>75.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Morwa</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>83.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Nizwa</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>76.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Tura</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>76.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bida</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>82.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>82.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Booue</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>83.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>88.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>85.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Puerto Narino</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>75.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mumford</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Alice Springs</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>81.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bandarbeyla</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>81.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pemangkat</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>81.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Banyo</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>81.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>85.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>81.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Salalah</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>86.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Iralaya</dd>\n<dt>Country</dt><dd>HN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>76.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Sinnamary</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>76.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>79.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Labuhan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>moderate rain</dd>\n<dt>Max Temperature</dt><dd>84.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>heavy intensity rain</dd>\n<dt>Max Temperature</dt><dd>79.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kambia</dd>\n<dt>Country</dt><dd>SL</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>78.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Galle</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>83.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Monteria</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>75.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>moderate rain</dd>\n<dt>Max Temperature</dt><dd>83.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Santa Rosa</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>83.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mecca</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kralendijk</dd>\n<dt>Country</dt><dd>BQ</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>80.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bosaso</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>81.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>81.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Broken Hill</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Toba Tek Singh</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>77.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Yulara</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>86.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Richards Bay</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>79.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Singarayakonda</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>85.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Charters Towers</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>87.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>San Policarpo</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>79.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Manati</dd>\n<dt>Country</dt><dd>PR</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kontagora</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>81.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Sulangan</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>San Andres</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ebolowa</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>76.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Tautira</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>77.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Aquin</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>75.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>77.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Brazzaville</dd>\n<dt>Country</dt><dd>CG</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>81.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Santa Marta</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Peravurani</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>86.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ambunti</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Uthal</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pilar</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>76.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Nisia Floresta</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>80.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Fougamou</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>81.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cayenne</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>75.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Luganville</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cuamba</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>89.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Noumea</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>82.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Saint-Pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>85.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Dorado</dd>\n<dt>Country</dt><dd>PR</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>77.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Katherine</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light intensity shower rain</dd>\n<dt>Max Temperature</dt><dd>79.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Dwarka</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>79.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bassila</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pontianak</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>85.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pedernales</dd>\n<dt>Country</dt><dd>DO</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>77.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Umm Lajj</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Buala</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>80.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>84.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Patancheru</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>86.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Olinda</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>80.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cartagena</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>78.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Trat</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>86.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Chake Chake</dd>\n<dt>Country</dt><dd>TZ</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>84.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Moussoro</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>82.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Nhulunbuy</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>84.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Popondetta</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>76.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Geraldton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Gladstone</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>78.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Puerto Escondido</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>76.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Tahoua</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>75.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Odweyne</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>77.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Neiafu</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>80.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Harlingen</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>75.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Nabire</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Takoradi</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>82.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Thayetmyo</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>87.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Auki</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>78.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>85.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>79.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cotonou</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>82.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ifakara</dd>\n<dt>Country</dt><dd>TZ</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>86.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mahibadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>82.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Vao</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>77.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Boa Vista</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>San Ramon De La Nueva Oran</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>76.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mbandaka</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>81.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Aboso</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>80.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>The Valley</dd>\n<dt>Country</dt><dd>AI</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>80.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Cap Malheureux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>85.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Porto Novo</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pangkalanbuun</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>82.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Malabo</dd>\n<dt>Country</dt><dd>GQ</dd>\n<dt>Current Weather</dt><dd>moderate rain</dd>\n<dt>Max Temperature</dt><dd>82.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ugoofaaru</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>82.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Dingle</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>78.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Manakara</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>86.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Gigmoto</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>79.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mayumba</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Sumbe</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Minab</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>80.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Kudahuvadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Veraval</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Luanda</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Pringsewu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Farafangana</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>84.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Eyl</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>84.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Matadi</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>81.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ambulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>82.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Keti Bandar</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>79.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Antalaha</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>84.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>80.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Gombong</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>81.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Ca Mau</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>83.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>80.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Fare</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>81.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Maceio</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>78.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Namatanai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Weather</dt><dd>moderate rain</dd>\n<dt>Max Temperature</dt><dd>78.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Omboue</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>82.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Carutapera</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>75.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Sri Aman</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Current Weather</dt><dd>light intensity shower rain</dd>\n<dt>Max Temperature</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Gorontalo</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>83.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Birnin Kebbi</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>76.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Salinopolis</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>77.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Catuday</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temperature</dt><dd>79.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Eydhafushi</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>82.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bangarapet</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>83.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Krabi</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>88.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bourail</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>80.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Mangrol</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n<dt>Max Temperature</dt><dd>81.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Touros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temperature</dt><dd>79.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Fomboni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temperature</dt><dd>81.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temperature</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Labuan</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temperature</dt><dd>88.16 °F</dd>\n</dl>\n']

# %%
# 4a. Add a marker layer for each city to the map.

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.35)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Bangarapet"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Bangarapet"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Singarayakonda"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Yarada"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Patancheru"] 
vacation_start
# Out:
#      City_ID        City Country  Max Temp Current Description      Lat   Lng  \
# 160      665  Bangarapet      IN     83.39       broken clouds  12.9667  78.2
#
#        Hotel Name
# 160  HGR Comforts

# %%
vacation_stop1
# Out:
#     City_ID            City Country  Max Temp Current Description    Lat  \
# 55      233  Singarayakonda      IN     85.53           clear sky  15.25
#
#         Lng           Hotel Name
# 55  80.0333  srinu tiffen center

# %%
vacation_stop2
# Out:
#    City_ID    City Country  Max Temp Current Description    Lat      Lng  \
# 3       11  Yarada      IN     84.52       broken clouds  17.65  83.2667
#
#   Hotel Name
# 3  Vishranti

# %%
vacation_stop3
# Out:
#     City_ID        City Country  Max Temp Current Description      Lat  \
# 91      395  Patancheru      IN     86.86           clear sky  17.5314
#
#        Lng           Hotel Name
# 91  78.265  Sri Ganapathi Lodge

# %%
vacation_end
# Out:
#      City_ID        City Country  Max Temp Current Description      Lat   Lng  \
# 160      665  Bangarapet      IN     83.39       broken clouds  12.9667  78.2
#
#        Hotel Name
# 160  HGR Comforts

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(vacation_start[["Lat", "Lng"]].values[0])
end = tuple(vacation_end[["Lat", "Lng"]].values[0])
stop1 = tuple(vacation_stop1[["Lat", "Lng"]].values[0])
stop2 = tuple(vacation_stop2[["Lat", "Lng"]].values[0])
stop3 = tuple(vacation_stop3[["Lat", "Lng"]].values[0])

# %%
start, end, stop1, stop2, stop3
# Out:
# ((12.9667, 78.2),
#  (12.9667, 78.2),
#  (15.25, 80.0333),
#  (17.65, 83.2667),
#  (17.5314, 78.265))

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3],travel_mode='DRIVING' or 'BICYCLING' or 'Walking')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0      665      Bangarapet      IN     83.39       broken clouds  12.9667
# 1      233  Singarayakonda      IN     85.53           clear sky  15.2500
# 2       11          Yarada      IN     84.52       broken clouds  17.6500
# 3      395      Patancheru      IN     86.86           clear sky  17.5314
#
#        Lng           Hotel Name
# 0  78.2000         HGR Comforts
# 1  80.0333  srinu tiffen center
# 2  83.2667            Vishranti
# 3  78.2650  Sri Ganapathi Lodge

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temperature</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp =  itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
